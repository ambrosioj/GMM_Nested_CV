# %%
import numpy as np
import pickle
import pandas as pd
# %matplotlib inline

# %%
load_file_3_features = open('../Data/results_3_features.pkl', "rb")
results_3_features = pickle.load(load_file_3_features)
print(results_3_features)
load_file_3_features.close()
# Out:
# {'train_accuracy_avg': array([0.99005464, 0.99502732, 0.98844262, 0.99338798, 0.98174863,
#        0.98669399, 0.99502732, 0.99008197, 0.99669399, 0.99172131]), 'train_accuracy_std': array([0.01102296, 0.00759622, 0.01290593, 0.01092404, 0.01167904,
#        0.00999122, 0.00759622, 0.01092421, 0.0066123 , 0.01114007]), 'train_fmacro_avg': array([0.99134716, 0.99543321, 0.9898872 , 0.99411705, 0.98261578,
#        0.98788306, 0.99554005, 0.99095671, 0.99697932, 0.99249097]), 'train_fmacro_std': array([0.00946632, 0.0069841 , 0.0111083 , 0.00959942, 0.01212993,
#        0.00931663, 0.00681763, 0.00994112, 0.00604274, 0.00998902]), 'train_fmicro_avg': array([0.99005464, 0.99502732, 0.98844262, 0.99338798, 0.98174863,
#        0.98669399, 0.99502732, 0.99008197, 0.99669399, 0.99172131]), 'train_fmicro_std': array([0.01102296, 0.00759622, 0.01290593, 0.01092404, 0.01167904,
# ...

# %%
load_file_2_features = open('../Data/results_2_features.pkl', "rb")
results_2_features = pickle.load(load_file_2_features)
#print(results_2_features)
load_file_2_features.close()

# %%
load_file_1_features = open('../Data/results_1_features.pkl', "rb")
results_1_features = pickle.load(load_file_1_features)
#print(results_1_features)
load_file_1_features.close()

# %%
df_3_features = pd.DataFrame()
df_3_features["train_accuracy_avg"] = results_3_features["train_accuracy_avg"]
df_3_features["train_accuracy_std"] = results_3_features["train_accuracy_std"]
df_3_features["train_fmacro_avg"] = results_3_features["train_fmacro_avg"]
df_3_features["train_fmacro_std"] = results_3_features["train_fmacro_std"]
df_3_features["train_fmicro_avg"] = results_3_features["train_fmicro_avg"]
df_3_features["train_fmicro_std"] = results_3_features["train_fmicro_std"]

df_3_features["test_accuracy_avg"] = results_3_features["test_accuracy_avg"]
df_3_features["test_accuracy_std"] = results_3_features["test_accuracy_std"]
df_3_features["test_fmacro_avg"] = results_3_features["test_fmacro_avg"]
df_3_features["test_fmacro_std"] = results_3_features["test_fmacro_std"]
df_3_features["test_fmicro_avg"] = results_3_features["test_fmicro_avg"]
df_3_features["test_fmicro_std"] = results_3_features["test_fmicro_std"]

df_3_features["kernel"] = results_3_features["best_params"]["kernel"]
df_3_features["C"] = results_3_features["best_params"]["C"]
df_3_features["gamma"] = results_3_features["best_params"]["gamma"]
df_3_features["degree"] = results_3_features["best_params"]["degree"]
df_3_features["coef0"] = results_3_features["best_params"]["coef0"]
df_3_features["N_features"] = '3'
df_3_features
# Out:
#    train_accuracy_avg  train_accuracy_std  train_fmacro_avg  train_fmacro_std  \
# 0            0.990055            0.011023          0.991347          0.009466
# 1            0.995027            0.007596          0.995433          0.006984
# 2            0.988443            0.012906          0.989887          0.011108
# 3            0.993388            0.010924          0.994117          0.009599
# 4            0.981749            0.011679          0.982616          0.012130
# 5            0.986694            0.009991          0.987883          0.009317
# 6            0.995027            0.007596          0.995540          0.006818
# 7            0.990082            0.010924          0.990957          0.009941
# 8            0.996694            0.006612          0.996979          0.006043
# 9            0.991721            0.011140          0.992491          0.009989
#
#    train_fmicro_avg  train_fmicro_std  test_accuracy_avg  test_accuracy_std  \
# ...

# %%
df_2_features = pd.DataFrame()
df_2_features["train_accuracy_avg"] = results_2_features["train_accuracy_avg"]
df_2_features["train_accuracy_std"] = results_2_features["train_accuracy_std"]
df_2_features["train_fmacro_avg"] = results_2_features["train_fmacro_avg"]
df_2_features["train_fmacro_std"] = results_2_features["train_fmacro_std"]
df_2_features["train_fmicro_avg"] = results_2_features["train_fmicro_avg"]
df_2_features["train_fmicro_std"] = results_2_features["train_fmicro_std"]

df_2_features["test_accuracy_avg"] = results_2_features["test_accuracy_avg"]
df_2_features["test_accuracy_std"] = results_2_features["test_accuracy_std"]
df_2_features["test_fmacro_avg"] = results_2_features["test_fmacro_avg"]
df_2_features["test_fmacro_std"] = results_2_features["test_fmacro_std"]
df_2_features["test_fmicro_avg"] = results_2_features["test_fmicro_avg"]
df_2_features["test_fmicro_std"] = results_2_features["test_fmicro_std"]

df_2_features["kernel"] = results_2_features["best_params"]["kernel"]
df_2_features["C"] = results_2_features["best_params"]["C"]
df_2_features["gamma"] = results_2_features["best_params"]["gamma"]
df_2_features["degree"] = results_2_features["best_params"]["degree"]
df_2_features["coef0"] = results_2_features["best_params"]["coef0"]
df_2_features["N_features"] = '2'
#df_2_features

# %%
df_1_features = pd.DataFrame()
df_1_features["train_accuracy_avg"] = results_1_features["train_accuracy_avg"]
df_1_features["train_accuracy_std"] = results_1_features["train_accuracy_std"]
df_1_features["train_fmacro_avg"] = results_1_features["train_fmacro_avg"]
df_1_features["train_fmacro_std"] = results_1_features["train_fmacro_std"]
df_1_features["train_fmicro_avg"] = results_1_features["train_fmicro_avg"]
df_1_features["train_fmicro_std"] = results_1_features["train_fmicro_std"]

df_1_features["test_accuracy_avg"] = results_1_features["test_accuracy_avg"]
df_1_features["test_accuracy_std"] = results_1_features["test_accuracy_std"]
df_1_features["test_fmacro_avg"] = results_1_features["test_fmacro_avg"]
df_1_features["test_fmacro_std"] = results_1_features["test_fmacro_std"]
df_1_features["test_fmicro_avg"] = results_1_features["test_fmicro_avg"]
df_1_features["test_fmicro_std"] = results_1_features["test_fmicro_std"]

df_1_features["kernel"] = results_1_features["best_params"]["kernel"]
df_1_features["C"] = results_1_features["best_params"]["C"]
df_1_features["gamma"] = results_1_features["best_params"]["gamma"]
df_1_features["degree"] = results_1_features["best_params"]["degree"]
df_1_features["coef0"] = results_1_features["best_params"]["coef0"]
df_1_features["N_features"] = '1'
#df_1_features

# %%
df_results = pd.concat([df_3_features, df_2_features, df_1_features], ignore_index=True)
df_results
# Out:
#     train_accuracy_avg  train_accuracy_std  train_fmacro_avg  \
# 0             0.990055            0.011023          0.991347
# 1             0.995027            0.007596          0.995433
# 2             0.988443            0.012906          0.989887
# 3             0.993388            0.010924          0.994117
# 4             0.981749            0.011679          0.982616
# 5             0.986694            0.009991          0.987883
# 6             0.995027            0.007596          0.995540
# 7             0.990082            0.010924          0.990957
# 8             0.996694            0.006612          0.996979
# 9             0.991721            0.011140          0.992491
# 10            0.991721            0.008279          0.992516
# 11            0.998333            0.005000          0.998412
# 12            0.991776            0.013234          0.992556
# 13            0.991694            0.011160          0.991716
# ...

# %%
kernel_counts = df_results["kernel"].value_counts()
kernel_counts
# Out:
# rbf       23
# linear     4
# poly       3
# Name: kernel, dtype: int64

# %%
for kernel in df_results["kernel"].unique():
     print(f'Kernel: {kernel} \nGamma Values: \
     {df_results["gamma"][df_results.kernel == kernel].value_counts()}\n \n')
# Out:
# Kernel: rbf
# Gamma Values:      0.0010    17
# 0.0001     6
# Name: gamma, dtype: int64
#
#
# Kernel: poly
# Gamma Values:      0.1    3
# Name: gamma, dtype: int64
#
#
# Kernel: linear
# Gamma Values:      Series([], Name: gamma, dtype: int64)

# %%
df_results[df_results.test_accuracy_avg == max(df_results.test_accuracy_avg)]
# Out:
#    train_accuracy_avg  train_accuracy_std  train_fmacro_avg  train_fmacro_std  \
# 4            0.981749            0.011679          0.982616           0.01213
#
#    train_fmicro_avg  train_fmicro_std  test_accuracy_avg  test_accuracy_std  \
# 4          0.981749          0.011679           0.985714           0.042857
#
#    test_fmacro_avg  test_fmacro_std  test_fmicro_avg  test_fmicro_std  kernel  \
# 4         0.985714         0.042857         0.985714         0.042857  linear
#
#    C  gamma  degree  coef0 N_features
# 4  1    NaN     NaN    NaN          3

# %%
df_results[df_results.test_accuracy_std == min(df_results.test_accuracy_std)]
# Out:
#    train_accuracy_avg  train_accuracy_std  train_fmacro_avg  train_fmacro_std  \
# 4            0.981749            0.011679          0.982616           0.01213
#
#    train_fmicro_avg  train_fmicro_std  test_accuracy_avg  test_accuracy_std  \
# 4          0.981749          0.011679           0.985714           0.042857
#
#    test_fmacro_avg  test_fmacro_std  test_fmicro_avg  test_fmicro_std  kernel  \
# 4         0.985714         0.042857         0.985714         0.042857  linear
#
#    C  gamma  degree  coef0 N_features
# 4  1    NaN     NaN    NaN          3

# %%
df_2_features[~df_2_features.apply(tuple,1).isin(df_1_features.apply(tuple,1))]
# Out:
#    train_accuracy_avg  train_accuracy_std  train_fmacro_avg  train_fmacro_std  \
# 0            0.991721            0.008279          0.992516          0.007503
# 1            0.998333            0.005000          0.998412          0.004764
# 2            0.991776            0.013234          0.992556          0.011970
# 3            0.991694            0.011160          0.991716          0.010808
# 4            0.986721            0.012458          0.987153          0.012979
# 5            0.985055            0.008966          0.986436          0.008401
# 6            0.991721            0.008279          0.992428          0.007581
# 7            0.986749            0.012378          0.988053          0.011054
# 8            0.995027            0.007596          0.995480          0.006905
# 9            0.991721            0.011140          0.992491          0.009989
#
#    train_fmicro_avg  train_fmicro_std  test_accuracy_avg  test_accuracy_std  \
# ...

# %%
df_results_grouped = df_results.groupby(["kernel","C","gamma","degree","coef0","N_features"], dropna=False).mean()\
.sort_values("N_features")
df_results_grouped
# Out:
#                                            train_accuracy_avg  \
# kernel C   gamma  degree coef0 N_features
# linear 1   NaN    NaN    NaN   1                     0.991721
# poly   1   0.1000 3.0    0.0   1                     0.991721
# rbf    1   0.0010 NaN    NaN   1                     0.993370
#        10  0.0001 NaN    NaN   1                     0.988374
#        100 0.0010 NaN    NaN   1                     0.990073
# linear 1   NaN    NaN    NaN   2                     0.991721
# poly   1   0.1000 3.0    0.0   2                     0.991721
# rbf    1   0.0010 NaN    NaN   2                     0.993370
#        10  0.0001 NaN    NaN   2                     0.988374
#        100 0.0010 NaN    NaN   2                     0.990073
# linear 1   NaN    NaN    NaN   3                     0.988388
# poly   1   0.1000 3.0    0.0   3                     0.988443
# rbf    1   0.0010 NaN    NaN   3                     0.992832
# ...

# %%
df_agg = df_results.groupby(["kernel","C","gamma","degree","coef0","N_features"]\
                            , dropna=False) \
                   .agg({'kernel':'size',\
                         'test_accuracy_avg':'mean',\
                         'test_accuracy_std':'mean',\
                         'test_fmacro_avg':'mean',\
                         'test_fmacro_std':'mean',\
                         'test_fmicro_avg':'mean',\
                         'test_fmicro_std':'mean'}) \
                   .rename(columns={'kernel':'Frequency',\
                                    'N_features': 'N',\
                                    'test_accuracy_avg':'accuracy_avg',\
                                    'test_accuracy_std':'accuracy_std',\
                                    'test_fmacro_avg':'fmacro_avg',\
                                    'test_fmacro_std':'fmacro_std',\
                                    'test_fmicro_avg':'fmicro_avg',\
                                    'test_fmicro_std':'fmicro_std'}) \
                   .reset_index()
df_agg = df_agg.sort_values(['Frequency','accuracy_avg'], ascending=False)\
               .rename(columns={'N_features': 'N'})\
               .reset_index(drop=True)
df_agg.round({'accuracy_avg': 3, 'accuracy_std': 3, 'fmacro_avg': 3, \
                    'fmacro_std': 3, 'fmicro_avg': 3, 'fmicro_std': 3})
# Out:
#     kernel    C   gamma  degree  coef0  N  Frequency  accuracy_avg  \
# 0      rbf    1  0.0010     NaN    NaN  3          3         0.956
# 1      rbf    1  0.0010     NaN    NaN  1          3         0.948
# 2      rbf    1  0.0010     NaN    NaN  2          3         0.948
# 3      rbf  100  0.0010     NaN    NaN  1          3         0.936
# 4      rbf  100  0.0010     NaN    NaN  2          3         0.936
# 5      rbf   10  0.0001     NaN    NaN  1          2         0.955
# 6      rbf   10  0.0001     NaN    NaN  2          2         0.955
# 7      rbf   10  0.0001     NaN    NaN  3          2         0.949
# 8   linear    1     NaN     NaN    NaN  3          2         0.949
# 9     poly    1  0.1000     3.0    0.0  1          1         0.957
# 10    poly    1  0.1000     3.0    0.0  2          1         0.957
# 11    poly    1  0.1000     3.0    0.0  3          1         0.957
# 12     rbf  100  0.0010     NaN    NaN  3          1         0.955
# ...

# %%
print(df_agg.round({'accuracy_avg': 3, 'accuracy_std': 3, 'fmacro_avg': 3, \
                    'fmacro_std': 3, 'fmicro_avg': 3, 'fmicro_std': 3}).to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrlrrrrrrr}
# \toprule
# kernel &   C &  gamma &  degree &  coef0 & N &  Frequency &  accuracy\_avg &  accuracy\_std &  fmacro\_avg &  fmacro\_std &  fmicro\_avg &  fmicro\_std \\
# \midrule
#    rbf &   1 & 0.0010 &     NaN &    NaN & 3 &          3 &         0.956 &         0.075 &       0.943 &       0.101 &       0.956 &       0.075 \\
#    rbf &   1 & 0.0010 &     NaN &    NaN & 1 &          3 &         0.948 &         0.085 &       0.937 &       0.108 &       0.948 &       0.085 \\
#    rbf &   1 & 0.0010 &     NaN &    NaN & 2 &          3 &         0.948 &         0.085 &       0.937 &       0.108 &       0.948 &       0.085 \\
#    rbf & 100 & 0.0010 &     NaN &    NaN & 1 &          3 &         0.936 &         0.090 &       0.908 &       0.146 &       0.936 &       0.090 \\
#    rbf & 100 & 0.0010 &     NaN &    NaN & 2 &          3 &         0.936 &         0.090 &       0.908 &       0.146 &       0.936 &       0.090 \\
# ...

# %%
df_results_best = df_results[(df_results.kernel == df_agg['kernel'][0]) & \
                             (df_results.C == df_agg['C'][0]) &\
                             (df_results.gamma == df_agg['gamma'][0]) &\
                             (df_results.N_features == df_agg['N'][0])]\
                            .reset_index(drop=True)
df_results_best
# Out:
#    train_accuracy_avg  train_accuracy_std  train_fmacro_avg  train_fmacro_std  \
# 0            0.995027            0.007596          0.995433          0.006984
# 1            0.993388            0.010924          0.994117          0.009599
# 2            0.990082            0.010924          0.990957          0.009941
#
#    train_fmicro_avg  train_fmicro_std  test_accuracy_avg  test_accuracy_std  \
# 0          0.995027          0.007596           0.957143           0.091473
# 1          0.993388          0.010924           0.954762           0.069375
# 2          0.990082          0.010924           0.957143           0.065465
#
#    test_fmacro_avg  test_fmacro_std  test_fmicro_avg  test_fmicro_std kernel  \
# 0         0.963571         0.078925         0.957143         0.091473    rbf
# 1         0.909630         0.152736         0.954762         0.069375    rbf
# 2         0.954921         0.070385         0.957143         0.065465    rbf
#
# ...
